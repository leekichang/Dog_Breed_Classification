# %% [markdown]
# # Import Packages

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torch.nn.functional as F

import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import sklearn.metrics as metrics

import utils

# %% [markdown]
# # Hyper-Parameters

# %%
DATASET_DIR = './data/'

BATCH_SIZE = 256
LEARNING_RATE = 0.005
EPOCHS = 15

SaveModelName = "efficientnet_b6"

ModelSavePath = "./Saved_model/" + SaveModelName + "/"
if not os.path.isdir(ModelSavePath):
    os.mkdir(ModelSavePath)

USE_CUDA = torch.cuda.is_available() 
DEVICE = torch.device("cuda" if USE_CUDA else "cpu") 
print("Working with", DEVICE)
# Out:
# Working with cuda

# %%
TRAIN_SET, TEST_SET, train_loader, test_loader = utils.load_dataset()

# %%
import torchvision.models as models
model_transfer = models.efficientnet_b6(pretrained=True)
n_dog_breed_classes = 120
model_transfer
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 56, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(56, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(56, 56, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=56, bias=False)
#             (1): BatchNorm2d(56, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(56, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 56, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): ConvNormActivation(
#             (0): Conv2d(56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): ConvNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0044444444444444444, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): ConvNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.008888888888888889, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.013333333333333336, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.017777777777777778, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.022222222222222223, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.026666666666666672, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.031111111111111114, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.035555555555555556, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.044444444444444446, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.04888888888888889, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.053333333333333344, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05777777777777778, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06222222222222223, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(432, 432, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=432, bias=False)
#             (1): BatchNorm2d(432, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(432, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 432, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06666666666666667, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07111111111111111, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07555555555555557, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08444444444444445, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08888888888888889, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09333333333333334, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09777777777777778, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(864, 864, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=864, bias=False)
#             (1): BatchNorm2d(864, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(864, 36, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(36, 864, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10222222222222223, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10666666666666669, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1111111111111111, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11555555555555556, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12000000000000001, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12444444444444445, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.12888888888888891, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13333333333333333, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1200, 1200, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=1200, bias=False)
#             (1): BatchNorm2d(1200, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1200, 50, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(50, 1200, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13777777777777778, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14222222222222222, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14666666666666667, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15111111111111114, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15555555555555556, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16444444444444445, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1688888888888889, mode=row)
#       )
#       (8): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17333333333333334, mode=row)
#       )
#       (9): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17777777777777778, mode=row)
#       )
#       (10): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(344, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18222222222222226, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2064, 2064, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2064, bias=False)
#             (1): BatchNorm2d(2064, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2064, 86, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(86, 2064, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2064, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18666666666666668, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(3456, 3456, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3456, bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3456, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 3456, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1911111111111111, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(3456, 3456, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3456, bias=False)
#             (1): BatchNorm2d(3456, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(3456, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 3456, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19555555555555557, mode=row)
#       )
#     )
#     (8): ConvNormActivation(
#       (0): Conv2d(576, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=True)
#     (1): Linear(in_features=2304, out_features=1000, bias=True)
#   )
# )

# %%
for param in model_transfer.features.parameters():
    param.requires_grad = False

n_inputs = model_transfer.classifier[1].in_features

last_layer = nn.Linear(n_inputs, n_dog_breed_classes)

model_transfer.classifier[1] = last_layer

# %%
model_name = ['efficientnet_b6']
models = [model_transfer.to(DEVICE)]
criterion = nn.CrossEntropyLoss().to(DEVICE)

# %%
LOSSES_TRAIN, LOSSES_VAL = [[] for idx in range(len(models))], [[] for idx in range(len(models))]
ACCS_VAL = [[] for idx in range(len(models))]
SOTA_ACCS_VAL, SOTA_LOSS_VAL = [0 for idx in range(len(models))], [0 for idx in range(len(models))]
bestResult_pred_np, bestResult_anno_np = [[] for idx in range(len(models))], [[] for idx in range(len(models))]
bestModels = [0 for idx in range(len(models))]

for model_idx, model in enumerate(models):
    start = time.time()
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    for epoch in tqdm(range(EPOCHS), desc="EPOCHS"):
        model.train()
        LOSS_TRACE_FOR_TRAIN, LOSS_TRACE_FOR_VAL = [], []
        for idx, batch in enumerate(train_loader):
            optimizer.zero_grad()

            X_train, Y_train = batch
            X_train, Y_train = X_train.to(DEVICE), Y_train.to(DEVICE)

            Y_pred_train = model(X_train)
            Y_train = Y_train.squeeze(-1)

            LOSS_train = criterion(Y_pred_train, Y_train)

            LOSS_TRACE_FOR_TRAIN.append(LOSS_train.cpu().detach().numpy())
            LOSS_train.backward()
            optimizer.step()        

        with torch.no_grad():
            model.eval()
            Result_pred_val, Result_anno_val = [], []
            for idx, batch in enumerate(test_loader):
                X_val, Y_val = batch
                X_val, Y_val = X_val.to(DEVICE), Y_val.to(DEVICE)

                Y_pred_val = model(X_val)
                LOSS_val = criterion(Y_pred_val, Y_val)
                LOSS_TRACE_FOR_VAL.append(LOSS_val.cpu().detach().numpy())

                Y_pred_val_np  = Y_pred_val.to('cpu').detach().numpy()
                Y_pred_val_np  = np.argmax(Y_pred_val_np, axis=1).squeeze()
                Y_val_np       = Y_val.to('cpu').detach().numpy().reshape(-1, 1).squeeze()     
                
                Result_pred_val = np.hstack((Result_pred_val, Y_pred_val_np))
                Result_anno_val = np.hstack((Result_anno_val, Y_val_np))
                # Result_pred_val.append(list(Y_pred_val_np))
                # Result_anno_val.append(list(Y_val_np))
            
            Result_pred_np = np.array(Result_pred_val)
            Result_anno_np = np.array(Result_anno_val)
            Result_pred_np = np.reshape(Result_pred_np, (-1, 1))
            Result_anno_np = np.reshape(Result_anno_np, (-1, 1))
            
            ACC_VAL        = metrics.accuracy_score(Result_anno_np, Result_pred_np)
            AVG_LOSS_TRAIN = np.average(LOSS_TRACE_FOR_TRAIN)
            AVG_LOSS_VAL   = np.average(LOSS_TRACE_FOR_VAL)

            LOSSES_TRAIN[model_idx].append(AVG_LOSS_TRAIN)
            LOSSES_VAL[model_idx].append(AVG_LOSS_VAL)
            ACCS_VAL[model_idx].append(ACC_VAL)
            
            if ACC_VAL > SOTA_ACCS_VAL[model_idx]:
                SOTA_ACCS_VAL[model_idx] = ACC_VAL
                SOTA_LOSS_VAL[model_idx] = AVG_LOSS_VAL
                bestModels[model_idx] = model
                bestResult_pred_np[model_idx] = Result_pred_np
                bestResult_anno_np[model_idx] = Result_anno_np
                
            elif ACC_VAL == SOTA_ACCS_VAL[model_idx]:
                if AVG_LOSS_VAL < SOTA_LOSS_VAL[model_idx]:
                    SOTA_ACCS_VAL[model_idx] = ACC_VAL
                    SOTA_LOSS_VAL[model_idx] = AVG_LOSS_VAL
                    bestModels[model_idx] = model
                    bestResult_pred_np[model_idx] = Result_pred_np
                    bestResult_anno_np[model_idx] = Result_anno_np
                
            print(f'(epoch {epoch + 1:03d}/{EPOCHS}) Training Loss : {AVG_LOSS_TRAIN:.5f} | Validation Loss : {AVG_LOSS_VAL:.5f} | Validation Accuracy : {ACC_VAL*100:.2f} %')

    end = time.time()
    print(f"{model_name[model_idx]} Training took {end-start:.2f} sec")
    torch.save(bestModels[model_idx].state_dict(), ModelSavePath + model_name[model_idx] +'.pth')
# Out:
# EPOCHS:   0%|          | 0/20 [00:00<?, ?it/s]
# (epoch 001/20) Training Loss : 4.68514 | Validation Loss : 4.48621 | Validation Accuracy : 46.91 %
# (epoch 002/20) Training Loss : 4.44725 | Validation Loss : 4.21796 | Validation Accuracy : 60.41 %
# (epoch 003/20) Training Loss : 4.22700 | Validation Loss : 3.98988 | Validation Accuracy : 60.27 %
# (epoch 004/20) Training Loss : 4.01717 | Validation Loss : 3.79355 | Validation Accuracy : 60.56 %
# (epoch 005/20) Training Loss : 3.81435 | Validation Loss : 3.60595 | Validation Accuracy : 58.89 %
# (epoch 006/20) Training Loss : 3.62522 | Validation Loss : 3.43652 | Validation Accuracy : 58.82 %
# (epoch 007/20) Training Loss : 3.46006 | Validation Loss : 3.25715 | Validation Accuracy : 58.74 %
# (epoch 008/20) Training Loss : 3.28986 | Validation Loss : 3.10982 | Validation Accuracy : 59.36 %
# (epoch 009/20) Training Loss : 3.14597 | Validation Loss : 2.97207 | Validation Accuracy : 59.01 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35872/3068657360.py in <module>
#      29             model.eval()
#      30             Result_pred_val, Result_anno_val = [], []
# ---> 31             for idx, batch in enumerate(test_loader):
#      32                 X_val, Y_val = batch
#      33                 X_val, Y_val = X_val.to(DEVICE), Y_val.to(DEVICE)
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torchvision\datasets\folder.py in __getitem__(self, index)
#     232         sample = self.loader(path)
#     233         if self.transform is not None:
# --> 234             sample = self.transform(sample)
#     235         if self.target_transform is not None:
#     236             target = self.target_transform(target)
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torchvision\transforms\transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torchvision\transforms\transforms.py in forward(self, img)
#     917         """
#     918         i, j, h, w = self.get_params(img, self.scale, self.ratio)
# --> 919         return F.resized_crop(img, i, j, h, w, self.size, self.interpolation)
#     920
#     921     def __repr__(self):
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torchvision\transforms\functional.py in resized_crop(img, top, left, height, width, size, interpolation)
#     564     """
#     565     img = crop(img, top, left, height, width)
# --> 566     img = resize(img, size, interpolation)
#     567     return img
#     568
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torchvision\transforms\functional.py in resize(img, size, interpolation, max_size, antialias)
#     417             )
#     418         pil_interpolation = pil_modes_mapping[interpolation]
# --> 419         return F_pil.resize(img, size=size, interpolation=pil_interpolation, max_size=max_size)
#     420
#     421     return F_t.resize(img, size=size, interpolation=interpolation.value, max_size=max_size, antialias=antialias)
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\torchvision\transforms\functional_pil.py in resize(img, size, interpolation, max_size)
#     263                 "i.e. size should be an int or a sequence of length 1 in torchscript mode."
#     264             )
# --> 265         return img.resize(size[::-1], interpolation)
#     266
#     267
#
# d:\Dog_Breed_Classification\IIE4123\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    2006                 )
#    2007
# -> 2008         return self._new(self.im.resize(size, resample, box))
#    2009
#    2010     def reduce(self, factor, box=None):
#
# KeyboardInterrupt:

# %%
utils.get_metrics(models = models, pred = bestResult_pred_np, anno = bestResult_anno_np)
